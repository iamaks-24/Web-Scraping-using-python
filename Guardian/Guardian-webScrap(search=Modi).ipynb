# %%
import pandas as pd
import requests

# %%
API_KEY="57c165d4-df33-45c1-9cb4-fed1058b8d66"

# %%
# https://content.guardianapis.com/search?page=2&q=debate&api-key=test
url="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=1"

# %%
urllist=[]

# %%
for i in range(1,26):
    a="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page="
    b=str(i)
    c=a+b
    urllist.append(c)

# %%
urllist #url lists containing urls for each page
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=57c165d4-df33-45c1-9cb4-fed1058b8d66&type=article&page=6',
# ...

# %%
info=[]

# %%
def json(url1):
    response=requests.get(url1)
    x=response.json()
    info.append(x)

# %%
output=[json(url1) for url1 in urllist]

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 243,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 25,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/article/2024/jun/23/india-open-letter-prosecution-arundhati-roy',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-06-23T15:59:48Z',
#      'webTitle': 'Open letter in India calls for withdrawal of go-ahead to prosecute Arundhati Roy',
#      'webUrl': 'https://www.theguardian.com/world/article/2024/jun/23/india-open-letter-prosecution-arundhati-roy',
# ...

# %%
info[0]['response']['pages']
# Out:
# 25

# %%
info[0]['response']['results'][1]['webTitle'] #page 1
# Out:
# 'The hounding of Arundhati Roy shows there’s still no room for dissent in India | Salil Tripathi'

# %%
info[24]['response']['results'][8]['webTitle'] #last page as it has only 3 articles so not working
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28408/3789351374.py in <module>
# ----> 1 info[24]['response']['results'][8]['webTitle'] #page 3
#
# IndexError: list index out of range

# %%
finallist=[]
finallist1=[]

# %%
try:
    for k in range(25):
        for j in range(10):#gvs error coz in last page v hv only 3 articles
            value=dict(webTitle=info[k]['response']['results'][j]['webTitle'],
            sectionname=info[k]['response']['results'][j]['sectionName'],
            publisheddate=info[k]['response']['results'][j]['webPublicationDate'])
            finallist1.append(value)
except Exception as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    for k in range(24):
        for j in range(10):
            value=dict(webTitle=info[k]['response']['results'][j]['webTitle'],
            sectionname=info[k]['response']['results'][j]['sectionName'],
            publisheddate=info[k]['response']['results'][j]['webPublicationDate'])
            finallist.append(value)
except Exception as e:
    print(e)

# %%
datanew=pd.DataFrame(finallist)
datanew.to_excel('Articles_on_modi.xlsx')

# %%
datanew
# Out:
#                                               webTitle         sectionname  \
# 0    Open letter in India calls for withdrawal of g...          World news
# 1    The hounding of Arundhati Roy shows there’s st...             Opinion
# 2    Consensus or division? How Modi will manage In...          World news
# 3    India: author Arundhati Roy to be prosecuted o...          World news
# 4    Narendra Modi sworn in for third term as prime...          World news
# ..                                                 ...                 ...
# 235  Violent clashes as Indian farmers storm Delhi'...          World news
# 236  The Guardian view on India's farming revolt: a...             Opinion
# 237  'We are worried': Indians hopeful but anxious ...  Global development
# 238  Trump social media ban sparks calls for action...               Media
# 239  Mahatma Gandhi's killer venerated as Hindu nat...          World news
#
#             publisheddate
# 0    2024-06-23T15:59:48Z
# ...

# %%
x#in page one v hv 243 articles and pagesize is 10 then v should hv  61 pages
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 243,
#   'startIndex': 1,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 25,
#   'orderBy': 'newest',
#   'tag': {'id': 'world/narendra-modi',
#    'type': 'keyword',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webTitle': 'Narendra Modi',
#    'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#    'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#   'results': [{'id': 'world/article/2024/jun/23/india-open-letter-prosecution-arundhati-roy',
#     'type': 'article',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2024-06-23T15:59:48Z',
#     'webTitle': 'Open letter in India calls for withdrawal of go-ahead to prosecute Arundhati Roy',
#     'webUrl': 'https://www.theguardian.com/world/article/2024/jun/23/india-open-letter-prosecution-arundhati-roy',
# ...
